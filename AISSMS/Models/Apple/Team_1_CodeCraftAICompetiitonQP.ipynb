# %%
# !pip install kaggle

# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# Replace with the actual dataset name
# !kaggle datasets download -d recepbattal/leaf-disease-images

# !unzip leaf-disease-images.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: leaves/Apple/Apple_healthy/image (964).JPG
#   inflating: leaves/Apple/Apple_healthy/image (965).JPG
#   inflating: leaves/Apple/Apple_healthy/image (966).JPG
#   inflating: leaves/Apple/Apple_healthy/image (967).JPG
#   inflating: leaves/Apple/Apple_healthy/image (968).JPG
#   inflating: leaves/Apple/Apple_healthy/image (969).JPG
#   inflating: leaves/Apple/Apple_healthy/image (97).JPG
#   inflating: leaves/Apple/Apple_healthy/image (970).JPG
#   inflating: leaves/Apple/Apple_healthy/image (971).JPG
#   inflating: leaves/Apple/Apple_healthy/image (972).JPG
#   inflating: leaves/Apple/Apple_healthy/image (973).JPG
#   inflating: leaves/Apple/Apple_healthy/image (974).JPG
#   inflating: leaves/Apple/Apple_healthy/image (975).JPG
#   inflating: leaves/Apple/Apple_healthy/image (976).JPG
#   inflating: leaves/Apple/Apple_healthy/image (977).JPG
#   inflating: leaves/Apple/Apple_healthy/image (978).JPG
#   inflating: leaves/Apple/Apple_healthy/image (979).JPG
#   inflating: leaves/Apple/Apple_healthy/image (98).JPG
#   inflating: leaves/Apple/Apple_healthy/image (980).JPG
#   inflating: leaves/Apple/Apple_healthy/image (981).JPG
#   inflating: leaves/Apple/Apple_healthy/image (982).JPG
#   inflating: leaves/Apple/Apple_healthy/image (983).JPG
#   inflating: leaves/Apple/Apple_healthy/image (984).JPG
#   inflating: leaves/Apple/Apple_healthy/image (985).JPG
#   inflating: leaves/Apple/Apple_healthy/image (986).JPG
#   inflating: leaves/Apple/Apple_healthy/image (987).JPG
#   inflating: leaves/Apple/Apple_healthy/image (988).JPG
#   inflating: leaves/Apple/Apple_healthy/image (989).JPG
#   inflating: leaves/Apple/Apple_healthy/image (99).JPG
#   inflating: leaves/Apple/Apple_healthy/image (990).JPG
#   inflating: leaves/Apple/Apple_healthy/image (991).JPG
#   inflating: leaves/Apple/Apple_healthy/image (992).JPG
#   inflating: leaves/Apple/Apple_healthy/image (993).JPG
#   inflating: leaves/Apple/Apple_healthy/image (994).JPG
#   inflating: leaves/Apple/Apple_healthy/image (995).JPG
#   inflating: leaves/Apple/Apple_healthy/image (996).JPG
#   inflating: leaves/Apple/Apple_healthy/image (997).JPG
#   inflating: leaves/Apple/Apple_healthy/image (998).JPG
#   inflating: leaves/Apple/Apple_healthy/image (999).JPG
#   inflating: leaves/Apple/Apple_rust/image (1).JPG
#   inflating: leaves/Apple/Apple_rust/image (10).JPG
#   inflating: leaves/Apple/Apple_rust/image (100).JPG
#   inflating: leaves/Apple/Apple_rust/image (101).JPG
#   inflating: leaves/Apple/Apple_rust/image (102).JPG
#   inflating: leaves/Apple/Apple_rust/image (103).JPG
#   inflating: leaves/Apple/Apple_rust/image (104).JPG
#   inflating: leaves/Apple/Apple_rust/image (105).JPG
#   inflating: leaves/Apple/Apple_rust/image (106).JPG
#   inflating: leaves/Apple/Apple_rust/image (107).JPG
#   inflating: leaves/Apple/Apple_rust/image (108).JPG
#   inflating: leaves/Apple/Apple_rust/image (109).JPG
#   inflating: leaves/Apple/Apple_rust/image (11).JPG
#   inflating: leaves/Apple/Apple_rust/image (110).JPG
#   inflating: leaves/Apple/Apple_rust/image (111).JPG
#   inflating: leaves/Apple/Apple_rust/image (112).JPG
#   inflating: leaves/Apple/Apple_rust/image (113).JPG
#   inflating: leaves/Apple/Apple_rust/image (114).JPG
#   inflating: leaves/Apple/Apple_rust/image (115).JPG
#   inflating: leaves/Apple/Apple_rust/image (116).JPG
#   inflating: leaves/Apple/Apple_rust/image (117).JPG
#   inflating: leaves/Apple/Apple_rust/image (118).JPG
#   inflating: leaves/Apple/Apple_rust/image (119).JPG
#   inflating: leaves/Apple/Apple_rust/image (12).JPG
#   inflating: leaves/Apple/Apple_rust/image (120).JPG
#   inflating: leaves/Apple/Apple_rust/image (121).JPG
#   inflating: leaves/Apple/Apple_rust/image (122).JPG
#   inflating: leaves/Apple/Apple_rust/image (123).JPG
#   inflating: leaves/Apple/Apple_rust/image (124).JPG
#   inflating: leaves/Apple/Apple_rust/image (125).JPG
#   inflating: leaves/Apple/Apple_rust/image (126).JPG
#   inflating: leaves/Apple/Apple_rust/image (127).JPG
#   inflating: leaves/Apple/Apple_rust/image (128).JPG
#   inflating: leaves/Apple/Apple_rust/image (129).JPG
#   inflating: leaves/Apple/Apple_rust/image (13).JPG
#   inflating: leaves/Apple/Apple_rust/image (130).JPG
#   inflating: leaves/Apple/Apple_rust/image (131).JPG
#   inflating: leaves/Apple/Apple_rust/image (132).JPG
#   inflating: leaves/Apple/Apple_rust/image (133).JPG
#   inflating: leaves/Apple/Apple_rust/image (134).JPG
#   inflating: leaves/Apple/Apple_rust/image (135).JPG
#   inflating: leaves/Apple/Apple_rust/image (136).JPG
#   inflating: leaves/Apple/Apple_rust/image (137).JPG
#   inflating: leaves/Apple/Apple_rust/image (138).JPG
#   inflating: leaves/Apple/Apple_rust/image (139).JPG
#   inflating: leaves/Apple/Apple_rust/image (14).JPG
#   inflating: leaves/Apple/Apple_rust/image (140).JPG
#   inflating: leaves/Apple/Apple_rust/image (141).JPG
#   inflating: leaves/Apple/Apple_rust/image (142).JPG
#   inflating: leaves/Apple/Apple_rust/image (143).JPG
#   inflating: leaves/Apple/Apple_rust/image (144).JPG
#   inflating: leaves/Apple/Apple_rust/image (145).JPG
#   inflating: leaves/Apple/Apple_rust/image (146).JPG
#   inflating: leaves/Apple/Apple_rust/image (147).JPG
#   inflating: leaves/Apple/Apple_rust/image (148).JPG
#   inflating: leaves/Apple/Apple_rust/image (149).JPG
#   inflating: leaves/Apple/Apple_rust/image (15).JPG
#   inflating: leaves/Apple/Apple_rust/image (150).JPG
#   inflating: leaves/Apple/Apple_rust/image (151).JPG
#   inflating: leaves/Apple/Apple_rust/image (152).JPG
#   inflating: leaves/Apple/Apple_rust/image (153).JPG
#   inflating: leaves/Apple/Apple_rust/image (154).JPG
#   inflating: leaves/Apple/Apple_rust/image (155).JPG
#   inflating: leaves/Apple/Apple_rust/image (156).JPG
#   inflating: leaves/Apple/Apple_rust/image (157).JPG
#   inflating: leaves/Apple/Apple_rust/image (158).JPG
#   inflating: leaves/Apple/Apple_rust/image (159).JPG
#   inflating: leaves/Apple/Apple_rust/image (16).JPG
#   inflating: leaves/Apple/Apple_rust/image (160).JPG
#   inflating: leaves/Apple/Apple_rust/image (161).JPG
#   inflating: leaves/Apple/Apple_rust/image (162).JPG
#   inflating: leaves/Apple/Apple_rust/image (163).JPG
#   inflating: leaves/Apple/Apple_rust/image (164).JPG
#   inflating: leaves/Apple/Apple_rust/image (165).JPG
#   inflating: leaves/Apple/Apple_rust/image (166).JPG
#   inflating: leaves/Apple/Apple_rust/image (167).JPG
#   inflating: leaves/Apple/Apple_rust/image (168).JPG
#   inflating: leaves/Apple/Apple_rust/image (169).JPG
#   inflating: leaves/Apple/Apple_rust/image (17).JPG
#   inflating: leaves/Apple/Apple_rust/image (170).JPG
#   inflating: leaves/Apple/Apple_rust/image (171).JPG
#   inflating: leaves/Apple/Apple_rust/image (172).JPG
#   inflating: leaves/Apple/Apple_rust/image (173).JPG
#   inflating: leaves/Apple/Apple_rust/image (174).JPG
#   inflating: leaves/Apple/Apple_rust/image (175).JPG
#   inflating: leaves/Apple/Apple_rust/image (176).JPG
#   inflating: leaves/Apple/Apple_rust/image (177).JPG
#   inflating: leaves/Apple/Apple_rust/image (178).JPG
#   inflating: leaves/Apple/Apple_rust/image (179).JPG
#   inflating: leaves/Apple/Apple_rust/image (18).JPG
#   inflating: leaves/Apple/Apple_rust/image (180).JPG
#   inflating: leaves/Apple/Apple_rust/image (181).JPG
#   inflating: leaves/Apple/Apple_rust/image (182).JPG
#   inflating: leaves/Apple/Apple_rust/image (183).JPG
#   inflating: leaves/Apple/Apple_rust/image (184).JPG
#   inflating: leaves/Apple/Apple_rust/image (185).JPG
#   inflating: leaves/Apple/Apple_rust/image (186).JPG
#   inflating: leaves/Apple/Apple_rust/image (187).JPG
#   inflating: leaves/Apple/Apple_rust/image (188).JPG
#   inflating: leaves/Apple/Apple_rust/image (189).JPG
#   inflating: leaves/Apple/Apple_rust/image (19).JPG
#   inflating: leaves/Apple/Apple_rust/image (190).JPG
#   inflating: leaves/Apple/Apple_rust/image (191).JPG
#   inflating: leaves/Apple/Apple_rust/image (192).JPG
#   inflating: leaves/Apple/Apple_rust/image (193).JPG
#   inflating: leaves/Apple/Apple_rust/image (194).JPG
#   inflating: leaves/Apple/Apple_rust/image (195).JPG
#   inflating: leaves/Apple/Apple_rust/image (196).JPG
#   inflating: leaves/Apple/Apple_rust/image (197).JPG
#   inflating: leaves/Apple/Apple_rust/image (198).JPG
#   inflating: leaves/Apple/Apple_rust/image (199).JPG
#   inflating: leaves/Apple/Apple_rust/image (2).JPG
#   inflating: leaves/Apple/Apple_rust/image (20).JPG
#   inflating: leaves/Apple/Apple_rust/image (200).JPG
#   inflating: leaves/Apple/Apple_rust/image (201).JPG
#   inflating: leaves/Apple/Apple_rust/image (202).JPG
#   inflating: leaves/Apple/Apple_rust/image (203).JPG
#   inflating: leaves/Apple/Apple_rust/image (204).JPG
#   inflating: leaves/Apple/Apple_rust/image (205).JPG
#   inflating: leaves/Apple/Apple_rust/image (206).JPG
#   inflating: leaves/Apple/Apple_rust/image (207).JPG
#   inflating: leaves/Apple/Apple_rust/image (208).JPG
#   inflating: leaves/Apple/Apple_rust/image (209).JPG
#   inflating: leaves/Apple/Apple_rust/image (21).JPG
#   inflating: leaves/Apple/Apple_rust/image (210).JPG
#   inflating: leaves/Apple/Apple_rust/image (211).JPG
#   inflating: leaves/Apple/Apple_rust/image (212).JPG
#   inflating: leaves/Apple/Apple_rust/image (213).JPG
#   inflating: leaves/Apple/Apple_rust/image (214).JPG
#   inflating: leaves/Apple/Apple_rust/image (215).JPG
#   inflating: leaves/Apple/Apple_rust/image (216).JPG
#   inflating: leaves/Apple/Apple_rust/image (217).JPG
#   inflating: leaves/Apple/Apple_rust/image (218).JPG
#   inflating: leaves/Apple/Apple_rust/image (219).JPG
#   inflating: leaves/Apple/Apple_rust/image (22).JPG
#   inflating: leaves/Apple/Apple_rust/image (220).JPG
#   inflating: leaves/Apple/Apple_rust/image (221).JPG
#   inflating: leaves/Apple/Apple_rust/image (222).JPG
#   inflating: leaves/Apple/Apple_rust/image (223).JPG
#   inflating: leaves/Apple/Apple_rust/image (224).JPG
#   inflating: leaves/Apple/Apple_rust/image (225).JPG
#   inflating: leaves/Apple/Apple_rust/image (226).JPG
#   inflating: leaves/Apple/Apple_rust/image (227).JPG
#   inflating: leaves/Apple/Apple_rust/image (228).JPG
#   inflating: leaves/Apple/Apple_rust/image (229).JPG
#   inflating: leaves/Apple/Apple_rust/image (23).JPG
#   inflating: leaves/Apple/Apple_rust/image (230).JPG
#   inflating: leaves/Apple/Apple_rust/image (231).JPG
#   inflating: leaves/Apple/Apple_rust/image (232).JPG
#   inflating: leaves/Apple/Apple_rust/image (233).JPG
#   inflating: leaves/Apple/Apple_rust/image (234).JPG
#   inflating: leaves/Apple/Apple_rust/image (235).JPG
#   inflating: leaves/Apple/Apple_rust/image (236).JPG
#   inflating: leaves/Apple/Apple_rust/image (237).JPG
#   inflating: leaves/Apple/Apple_rust/image (238).JPG
#   inflating: leaves/Apple/Apple_rust/image (239).JPG
#   inflating: leaves/Apple/Apple_rust/image (24).JPG
#   inflating: leaves/Apple/Apple_rust/image (240).JPG
#   inflating: leaves/Apple/Apple_rust/image (241).JPG
#   inflating: leaves/Apple/Apple_rust/image (242).JPG
#   inflating: leaves/Apple/Apple_rust/image (243).JPG
#   inflating: leaves/Apple/Apple_rust/image (244).JPG
#   inflating: leaves/Apple/Apple_rust/image (245).JPG
#   inflating: leaves/Apple/Apple_rust/image (246).JPG
#   inflating: leaves/Apple/Apple_rust/image (247).JPG
#   inflating: leaves/Apple/Apple_rust/image (248).JPG
#   inflating: leaves/Apple/Apple_rust/image (249).JPG
#   inflating: leaves/Apple/Apple_rust/image (25).JPG
#   inflating: leaves/Apple/Apple_rust/image (250).JPG
#   inflating: leaves/Apple/Apple_rust/image (251).JPG
#   inflating: leaves/Apple/Apple_rust/image (252).JPG
#   inflating: leaves/Apple/Apple_rust/image (253).JPG
#   inflating: leaves/Apple/Apple_rust/image (254).JPG
#   inflating: leaves/Apple/Apple_rust/image (255).JPG
#   inflating: leaves/Apple/Apple_rust/image (256).JPG
#   inflating: leaves/Apple/Apple_rust/image (257).JPG
#   inflating: leaves/Apple/Apple_rust/image (258).JPG
#   inflating: leaves/Apple/Apple_rust/image (259).JPG
#   inflating: leaves/Apple/Apple_rust/image (26).JPG
#   inflating: leaves/Apple/Apple_rust/image (260).JPG
#   inflating: leaves/Apple/Apple_rust/image (261).JPG
#   inflating: leaves/Apple/Apple_rust/image (262).JPG
#   inflating: leaves/Apple/Apple_rust/image (263).JPG
#   inflating: leaves/Apple/Apple_rust/image (264).JPG
#   inflating: leaves/Apple/Apple_rust/image (265).JPG
#   inflating: leaves/Apple/Apple_rust/image (266).JPG
#   inflating: leaves/Apple/Apple_rust/image (267).JPG
#   inflating: leaves/Apple/Apple_rust/image (268).JPG
#   inflating: leaves/Apple/Apple_rust/image (269).JPG
#   inflating: leaves/Apple/Apple_rust/image (27).JPG
#   inflating: leaves/Apple/Apple_rust/image (270).JPG
#   inflating: leaves/Apple/Apple_rust/image (271).JPG
#   inflating: leaves/Apple/Apple_rust/image (272).JPG
#   inflating: leaves/Apple/Apple_rust/image (273).JPG
#   inflating: leaves/Apple/Apple_rust/image (274).JPG
#   inflating: leaves/Apple/Apple_rust/image (275).JPG
#   inflating: leaves/Apple/Apple_rust/image (28).JPG
#   inflating: leaves/Apple/Apple_rust/image (29).JPG
#   inflating: leaves/Apple/Apple_rust/image (3).JPG
#   inflating: leaves/Apple/Apple_rust/image (30).JPG
#   inflating: leaves/Apple/Apple_rust/image (31).JPG
#   inflating: leaves/Apple/Apple_rust/image (32).JPG
#   inflating: leaves/Apple/Apple_rust/image (33).JPG
#   inflating: leaves/Apple/Apple_rust/image (34).JPG
#   inflating: leaves/Apple/Apple_rust/image (35).JPG
#   inflating: leaves/Apple/Apple_rust/image (36).JPG
#   inflating: leaves/Apple/Apple_rust/image (37).JPG
#   inflating: leaves/Apple/Apple_rust/image (38).JPG
#   inflating: leaves/Apple/Apple_rust/image (39).JPG
#   inflating: leaves/Apple/Apple_rust/image (4).JPG
#   inflating: leaves/Apple/Apple_rust/image (40).JPG
#   inflating: leaves/Apple/Apple_rust/image (41).JPG
#   inflating: leaves/Apple/Apple_rust/image (42).JPG
#   inflating: leaves/Apple/Apple_rust/image (43).JPG
#   inflating: leaves/Apple/Apple_rust/image (44).JPG
#   inflating: leaves/Apple/Apple_rust/image (45).JPG
#   inflating: leaves/Apple/Apple_rust/image (46).JPG
#   inflating: leaves/Apple/Apple_rust/image (47).JPG
#   inflating: leaves/Apple/Apple_rust/image (48).JPG
#   inflating: leaves/Apple/Apple_rust/image (49).JPG
#   inflating: leaves/Apple/Apple_rust/image (5).JPG
#   inflating: leaves/Apple/Apple_rust/image (50).JPG
#   inflating: leaves/Apple/Apple_rust/image (51).JPG
#   inflating: leaves/Apple/Apple_rust/image (52).JPG
#   inflating: leaves/Apple/Apple_rust/image (53).JPG
#   inflating: leaves/Apple/Apple_rust/image (54).JPG
#   inflating: leaves/Apple/Apple_rust/image (55).JPG
#   inflating: leaves/Apple/Apple_rust/image (56).JPG
#   inflating: leaves/Apple/Apple_rust/image (57).JPG
#   inflating: leaves/Apple/Apple_rust/image (58).JPG
#   inflating: leaves/Apple/Apple_rust/image (59).JPG
#   inflating: leaves/Apple/Apple_rust/image (6).JPG
#   inflating: leaves/Apple/Apple_rust/image (60).JPG
#   inflating: leaves/Apple/Apple_rust/image (61).JPG
#   inflating: leaves/Apple/Apple_rust/image (62).JPG
#   inflating: leaves/Apple/Apple_rust/image (63).JPG
#   inflating: leaves/Apple/Apple_rust/image (64).JPG
#   inflating: leaves/Apple/Apple_rust/image (65).JPG
#   inflating: leaves/Apple/Apple_rust/image (66).JPG
#   inflating: leaves/Apple/Apple_rust/image (67).JPG
#   inflating: leaves/Apple/Apple_rust/image (68).JPG
#   inflating: leaves/Apple/Apple_rust/image (69).JPG
#   inflating: leaves/Apple/Apple_rust/image (7).JPG
#   inflating: leaves/Apple/Apple_rust/image (70).JPG
#   inflating: leaves/Apple/Apple_rust/image (71).JPG
#   inflating: leaves/Apple/Apple_rust/image (72).JPG
#   inflating: leaves/Apple/Apple_rust/image (73).JPG
#   inflating: leaves/Apple/Apple_rust/image (74).JPG
#   inflating: leaves/Apple/Apple_rust/image (75).JPG
#   inflating: leaves/Apple/Apple_rust/image (76).JPG
#   inflating: leaves/Apple/Apple_rust/image (77).JPG
#   inflating: leaves/Apple/Apple_rust/image (78).JPG
#   inflating: leaves/Apple/Apple_rust/image (79).JPG
#   inflating: leaves/Apple/Apple_rust/image (8).JPG
#   inflating: leaves/Apple/Apple_rust/image (80).JPG
#   inflating: leaves/Apple/Apple_rust/image (81).JPG
#   inflating: leaves/Apple/Apple_rust/image (82).JPG
#   inflating: leaves/Apple/Apple_rust/image (83).JPG
#   inflating: leaves/Apple/Apple_rust/image (84).JPG
#   inflating: leaves/Apple/Apple_rust/image (85).JPG
#   inflating: leaves/Apple/Apple_rust/image (86).JPG
#   inflating: leaves/Apple/Apple_rust/image (87).JPG
#   inflating: leaves/Apple/Apple_rust/image (88).JPG
#   inflating: leaves/Apple/Apple_rust/image (89).JPG
#   inflating: leaves/Apple/Apple_rust/image (9).JPG
#   inflating: leaves/Apple/Apple_rust/image (90).JPG
#   inflating: leaves/Apple/Apple_rust/image (91).JPG
#   inflating: leaves/Apple/Apple_rust/image (92).JPG
#   inflating: leaves/Apple/Apple_rust/image (93).JPG
#   inflating: leaves/Apple/Apple_rust/image (94).JPG
#   inflating: leaves/Apple/Apple_rust/image (95).JPG
#   inflating: leaves/Apple/Apple_rust/image (96).JPG
#   inflating: leaves/Apple/Apple_rust/image (97).JPG
#   inflating: leaves/Apple/Apple_rust/image (98).JPG
#   inflating: leaves/Apple/Apple_rust/image (99).JPG
#   inflating: leaves/Apple/Apple_scab/image (1).JPG
#   inflating: leaves/Apple/Apple_scab/image (10).JPG
#   inflating: leaves/Apple/Apple_scab/image (100).JPG
#   inflating: leaves/Apple/Apple_scab/image (101).JPG
#   inflating: leaves/Apple/Apple_scab/image (102).JPG
#   inflating: leaves/Apple/Apple_scab/image (103).JPG
#   inflating: leaves/Apple/Apple_scab/image (104).JPG
#   inflating: leaves/Apple/Apple_scab/image (105).JPG
#   inflating: leaves/Apple/Apple_scab/image (106).JPG
#   inflating: leaves/Apple/Apple_scab/image (107).JPG
#   inflating: leaves/Apple/Apple_scab/image (108).JPG
#   inflating: leaves/Apple/Apple_scab/image (109).JPG
#   inflating: leaves/Apple/Apple_scab/image (11).JPG
#   inflating: leaves/Apple/Apple_scab/image (110).JPG
#   inflating: leaves/Apple/Apple_scab/image (111).JPG
#   inflating: leaves/Apple/Apple_scab/image (112).JPG
#   inflating: leaves/Apple/Apple_scab/image (113).JPG
#   inflating: leaves/Apple/Apple_scab/image (114).JPG
#   inflating: leaves/Apple/Apple_scab/image (115).JPG
#   inflating: leaves/Apple/Apple_scab/image (116).JPG
#   inflating: leaves/Apple/Apple_scab/image (117).JPG
#   inflating: leaves/Apple/Apple_scab/image (118).JPG
#   inflating: leaves/Apple/Apple_scab/image (119).JPG
#   inflating: leaves/Apple/Apple_scab/image (12).JPG
#   inflating: leaves/Apple/Apple_scab/image (120).JPG
#   inflating: leaves/Apple/Apple_scab/image (121).JPG
#   inflating: leaves/Apple/Apple_scab/image (122).JPG
#   inflating: leaves/Apple/Apple_scab/image (123).JPG
#   inflating: leaves/Apple/Apple_scab/image (124).JPG
#   inflating: leaves/Apple/Apple_scab/image (125).JPG
#   inflating: leaves/Apple/Apple_scab/image (126).JPG
#   inflating: leaves/Apple/Apple_scab/image (127).JPG
#   inflating: leaves/Apple/Apple_scab/image (128).JPG
#   inflating: leaves/Apple/Apple_scab/image (129).JPG
#   inflating: leaves/Apple/Apple_scab/image (13).JPG
#   inflating: leaves/Apple/Apple_scab/image (130).JPG
#   inflating: leaves/Apple/Apple_scab/image (131).JPG
#   inflating: leaves/Apple/Apple_scab/image (132).JPG
#   inflating: leaves/Apple/Apple_scab/image (133).JPG
#   inflating: leaves/Apple/Apple_scab/image (134).JPG
#   inflating: leaves/Apple/Apple_scab/image (135).JPG
#   inflating: leaves/Apple/Apple_scab/image (136).JPG
#   inflating: leaves/Apple/Apple_scab/image (137).JPG
#   inflating: leaves/Apple/Apple_scab/image (138).JPG
#   inflating: leaves/Apple/Apple_scab/image (139).JPG
#   inflating: leaves/Apple/Apple_scab/image (14).JPG
#   inflating: leaves/Apple/Apple_scab/image (140).JPG
#   inflating: leaves/Apple/Apple_scab/image (141).JPG
#   inflating: leaves/Apple/Apple_scab/image (142).JPG
#   inflating: leaves/Apple/Apple_scab/image (143).JPG
#   inflating: leaves/Apple/Apple_scab/image (144).JPG
#   inflating: leaves/Apple/Apple_scab/image (145).JPG
#   inflating: leaves/Apple/Apple_scab/image (146).JPG
#   inflating: leaves/Apple/Apple_scab/image (147).JPG
#   inflating: leaves/Apple/Apple_scab/image (148).JPG
#   inflating: leaves/Apple/Apple_scab/image (149).JPG
#   inflating: leaves/Apple/Apple_scab/image (15).JPG
#   inflating: leaves/Apple/Apple_scab/image (150).JPG
#   inflating: leaves/Apple/Apple_scab/image (151).JPG
#   inflating: leaves/Apple/Apple_scab/image (152).JPG
#   inflating: leaves/Apple/Apple_scab/image (153).JPG
#   inflating: leaves/Apple/Apple_scab/image (154).JPG
#   inflating: leaves/Apple/Apple_scab/image (155).JPG
#   inflating: leaves/Apple/Apple_scab/image (156).JPG
#   inflating: leaves/Apple/Apple_scab/image (157).JPG
#   inflating: leaves/Apple/Apple_scab/image (158).JPG
#   inflating: leaves/Apple/Apple_scab/image (159).JPG
#   inflating: leaves/Apple/Apple_scab/image (16).JPG
#   inflating: leaves/Apple/Apple_scab/image (160).JPG
#   inflating: leaves/Apple/Apple_scab/image (161).JPG
#   inflating: leaves/Apple/Apple_scab/image (162).JPG
#   inflating: leaves/Apple/Apple_scab/image (163).JPG
#   inflating: leaves/Apple/Apple_scab/image (164).JPG
#   inflating: leaves/Apple/Apple_scab/image (165).JPG
#   inflating: leaves/Apple/Apple_scab/image (166).JPG
#   inflating: leaves/Apple/Apple_scab/image (167).JPG
#   inflating: leaves/Apple/Apple_scab/image (168).JPG
#   inflating: leaves/Apple/Apple_scab/image (169).JPG
#   inflating: leaves/Apple/Apple_scab/image (17).JPG
#   inflating: leaves/Apple/Apple_scab/image (170).JPG
#   inflating: leaves/Apple/Apple_scab/image (171).JPG
#   inflating: leaves/Apple/Apple_scab/image (172).JPG
#   inflating: leaves/Apple/Apple_scab/image (173).JPG
#   inflating: leaves/Apple/Apple_scab/image (174).JPG
#   inflating: leaves/Apple/Apple_scab/image (175).JPG
#   inflating: leaves/Apple/Apple_scab/image (176).JPG
#   inflating: leaves/Apple/Apple_scab/image (177).JPG
#   inflating: leaves/Apple/Apple_scab/image (178).JPG
#   inflating: leaves/Apple/Apple_scab/image (179).JPG
#   inflating: leaves/Apple/Apple_scab/image (18).JPG
#   inflating: leaves/Apple/Apple_scab/image (180).JPG
#   inflating: leaves/Apple/Apple_scab/image (181).JPG
#   inflating: leaves/Apple/Apple_scab/image (182).JPG
#   inflating: leaves/Apple/Apple_scab/image (183).JPG
#   inflating: leaves/Apple/Apple_scab/image (184).JPG
#   inflating: leaves/Apple/Apple_scab/image (185).JPG
#   inflating: leaves/Apple/Apple_scab/image (186).JPG
#   inflating: leaves/Apple/Apple_scab/image (187).JPG
#   inflating: leaves/Apple/Apple_scab/image (188).JPG
#   inflating: leaves/Apple/Apple_scab/image (189).JPG
#   inflating: leaves/Apple/Apple_scab/image (19).JPG
#   inflating: leaves/Apple/Apple_scab/image (190).JPG
#   inflating: leaves/Apple/Apple_scab/image (191).JPG
#   inflating: leaves/Apple/Apple_scab/image (192).JPG
#   inflating: leaves/Apple/Apple_scab/image (193).JPG
#   inflating: leaves/Apple/Apple_scab/image (194).JPG
#   inflating: leaves/Apple/Apple_scab/image (195).JPG
#   inflating: leaves/Apple/Apple_scab/image (196).JPG
#   inflating: leaves/Apple/Apple_scab/image (197).JPG
#   inflating: leaves/Apple/Apple_scab/image (198).JPG
#   inflating: leaves/Apple/Apple_scab/image (199).JPG
#   inflating: leaves/Apple/Apple_scab/image (2).JPG
#   inflating: leaves/Apple/Apple_scab/image (20).JPG
#   inflating: leaves/Apple/Apple_scab/image (200).JPG
#   inflating: leaves/Apple/Apple_scab/image (201).JPG
#   inflating: leaves/Apple/Apple_scab/image (202).JPG
#   inflating: leaves/Apple/Apple_scab/image (203).JPG
#   inflating: leaves/Apple/Apple_scab/image (204).JPG
#   inflating: leaves/Apple/Apple_scab/image (205).JPG
#   inflating: leaves/Apple/Apple_scab/image (206).JPG
#   inflating: leaves/Apple/Apple_scab/image (207).JPG
#   inflating: leaves/Apple/Apple_scab/image (208).JPG
#   inflating: leaves/Apple/Apple_scab/image (209).JPG
#   inflating: leaves/Apple/Apple_scab/image (21).JPG
#   inflating: leaves/Apple/Apple_scab/image (210).JPG
#   inflating: leaves/Apple/Apple_scab/image (211).JPG
#   inflating: leaves/Apple/Apple_scab/image (212).JPG
#   inflating: leaves/Apple/Apple_scab/image (213).JPG
#   inflating: leaves/Apple/Apple_scab/image (214).JPG
#   inflating: leaves/Apple/Apple_scab/image (215).JPG
#   inflating: leaves/Apple/Apple_scab/image (216).JPG
#   inflating: leaves/Apple/Apple_scab/image (217).JPG
#   inflating: leaves/Apple/Apple_scab/image (218).JPG
#   inflating: leaves/Apple/Apple_scab/image (219).JPG
#   inflating: leaves/Apple/Apple_scab/image (22).JPG
#   inflating: leaves/Apple/Apple_scab/image (220).JPG
#   inflating: leaves/Apple/Apple_scab/image (221).JPG
#   inflating: leaves/Apple/Apple_scab/image (222).JPG
#   inflating: leaves/Apple/Apple_scab/image (223).JPG
#   inflating: leaves/Apple/Apple_scab/image (224).JPG
#   inflating: leaves/Apple/Apple_scab/image (225).JPG
#   inflating: leaves/Apple/Apple_scab/image (226).JPG
#   inflating: leaves/Apple/Apple_scab/image (227).JPG
#   inflating: leaves/Apple/Apple_scab/image (228).JPG
#   inflating: leaves/Apple/Apple_scab/image (229).JPG
#   inflating: leaves/Apple/Apple_scab/image (23).JPG
#   inflating: leaves/Apple/Apple_scab/image (230).JPG
#   inflating: leaves/Apple/Apple_scab/image (231).JPG
#   inflating: leaves/Apple/Apple_scab/image (232).JPG
#   inflating: leaves/Apple/Apple_scab/image (233).JPG
#   inflating: leaves/Apple/Apple_scab/image (234).JPG
#   inflating: leaves/Apple/Apple_scab/image (235).JPG
#   inflating: leaves/Apple/Apple_scab/image (236).JPG
#   inflating: leaves/Apple/Apple_scab/image (237).JPG
#   inflating: leaves/Apple/Apple_scab/image (238).JPG
#   inflating: leaves/Apple/Apple_scab/image (239).JPG
#   inflating: leaves/Apple/Apple_scab/image (24).JPG
#   inflating: leaves/Apple/Apple_scab/image (240).JPG
#   inflating: leaves/Apple/Apple_scab/image (241).JPG
#   inflating: leaves/Apple/Apple_scab/image (242).JPG
#   inflating: leaves/Apple/Apple_scab/image (243).JPG
#   inflating: leaves/Apple/Apple_scab/image (244).JPG
#   inflating: leaves/Apple/Apple_scab/image (245).JPG
#   inflating: leaves/Apple/Apple_scab/image (246).JPG
#   inflating: leaves/Apple/Apple_scab/image (247).JPG
#   inflating: leaves/Apple/Apple_scab/image (248).JPG
#   inflating: leaves/Apple/Apple_scab/image (249).JPG
#   inflating: leaves/Apple/Apple_scab/image (25).JPG
#   inflating: leaves/Apple/Apple_scab/image (250).JPG
#   inflating: leaves/Apple/Apple_scab/image (251).JPG
#   inflating: leaves/Apple/Apple_scab/image (252).JPG
#   inflating: leaves/Apple/Apple_scab/image (253).JPG
#   inflating: leaves/Apple/Apple_scab/image (254).JPG
#   inflating: leaves/Apple/Apple_scab/image (255).JPG
#   inflating: leaves/Apple/Apple_scab/image (256).JPG
#   inflating: leaves/Apple/Apple_scab/image (257).JPG
#   inflating: leaves/Apple/Apple_scab/image (258).JPG
#   inflating: leaves/Apple/Apple_scab/image (259).JPG
#   inflating: leaves/Apple/Apple_scab/image (26).JPG
#   inflating: leaves/Apple/Apple_scab/image (260).JPG
#   inflating: leaves/Apple/Apple_scab/image (261).JPG
#   inflating: leaves/Apple/Apple_scab/image (262).JPG
#   inflating: leaves/Apple/Apple_scab/image (263).JPG
#   inflating: leaves/Apple/Apple_scab/image (264).JPG
#   inflating: leaves/Apple/Apple_scab/image (265).JPG
#   inflating: leaves/Apple/Apple_scab/image (266).JPG
#   inflating: leaves/Apple/Apple_scab/image (267).JPG
#   inflating: leaves/Apple/Apple_scab/image (268).JPG
#   inflating: leaves/Apple/Apple_scab/image (269).JPG
#   inflating: leaves/Apple/Apple_scab/image (27).JPG
#   inflating: leaves/Apple/Apple_scab/image (270).JPG
#   inflating: leaves/Apple/Apple_scab/image (271).JPG
#   inflating: leaves/Apple/Apple_scab/image (272).JPG
#   inflating: leaves/Apple/Apple_scab/image (273).JPG
#   inflating: leaves/Apple/Apple_scab/image (274).JPG
#   inflating: leaves/Apple/Apple_scab/image (275).JPG
#   inflating: leaves/Apple/Apple_scab/image (276).JPG
#   inflating: leaves/Apple/Apple_scab/image (277).JPG
#   inflating: leaves/Apple/Apple_scab/image (278).JPG
#   inflating: leaves/Apple/Apple_scab/image (279).JPG
#   inflating: leaves/Apple/Apple_scab/image (28).JPG
#   inflating: leaves/Apple/Apple_scab/image (280).JPG
#   inflating: leaves/Apple/Apple_scab/image (281).JPG
#   inflating: leaves/Apple/Apple_scab/image (282).JPG
#   inflating: leaves/Apple/Apple_scab/image (283).JPG
#   inflating: leaves/Apple/Apple_scab/image (284).JPG
#   inflating: leaves/Apple/Apple_scab/image (285).JPG
#   inflating: leaves/Apple/Apple_scab/image (286).JPG
#   inflating: leaves/Apple/Apple_scab/image (287).JPG
#   inflating: leaves/Apple/Apple_scab/image (288).JPG
#   inflating: leaves/Apple/Apple_scab/image (289).JPG
#   inflating: leaves/Apple/Apple_scab/image (29).JPG
#   inflating: leaves/Apple/Apple_scab/image (290).JPG
#   inflating: leaves/Apple/Apple_scab/image (291).JPG
#   inflating: leaves/Apple/Apple_scab/image (292).JPG
#   inflating: leaves/Apple/Apple_scab/image (293).JPG
#   inflating: leaves/Apple/Apple_scab/image (294).JPG
#   inflating: leaves/Apple/Apple_scab/image (295).JPG
#   inflating: leaves/Apple/Apple_scab/image (296).JPG
#   inflating: leaves/Apple/Apple_scab/image (297).JPG
#   inflating: leaves/Apple/Apple_scab/image (298).JPG
#   inflating: leaves/Apple/Apple_scab/image (299).JPG
#   inflating: leaves/Apple/Apple_scab/image (3).JPG
#   inflating: leaves/Apple/Apple_scab/image (30).JPG
#   inflating: leaves/Apple/Apple_scab/image (300).JPG
#   inflating: leaves/Apple/Apple_scab/image (301).JPG
#   inflating: leaves/Apple/Apple_scab/image (302).JPG
#   inflating: leaves/Apple/Apple_scab/image (303).JPG
#   inflating: leaves/Apple/Apple_scab/image (304).JPG
#   inflating: leaves/Apple/Apple_scab/image (305).JPG
#   inflating: leaves/Apple/Apple_scab/image (306).JPG
#   inflating: leaves/Apple/Apple_scab/image (307).JPG
#   inflating: leaves/Apple/Apple_scab/image (308).JPG
#   inflating: leaves/Apple/Apple_scab/image (309).JPG
#   inflating: leaves/Apple/Apple_scab/image (31).JPG
#   inflating: leaves/Apple/Apple_scab/image (310).JPG
#   inflating: leaves/Apple/Apple_scab/image (311).JPG
#   inflating: leaves/Apple/Apple_scab/image (312).JPG
#   inflating: leaves/Apple/Apple_scab/image (313).JPG
#   inflating: leaves/Apple/Apple_scab/image (314).JPG
#   inflating: leaves/Apple/Apple_scab/image (315).JPG
#   inflating: leaves/Apple/Apple_scab/image (316).JPG
#   inflating: leaves/Apple/Apple_scab/image (317).JPG
#   inflating: leaves/Apple/Apple_scab/image (318).JPG
#   inflating: leaves/Apple/Apple_scab/image (319).JPG
#   inflating: leaves/Apple/Apple_scab/image (32).JPG
#   inflating: leaves/Apple/Apple_scab/image (320).JPG
#   inflating: leaves/Apple/Apple_scab/image (321).JPG
#   inflating: leaves/Apple/Apple_scab/image (322).JPG
#   inflating: leaves/Apple/Apple_scab/image (323).JPG
#   inflating: leaves/Apple/Apple_scab/image (324).JPG
#   inflating: leaves/Apple/Apple_scab/image (325).JPG
#   inflating: leaves/Apple/Apple_scab/image (326).JPG
#   inflating: leaves/Apple/Apple_scab/image (327).JPG
#   inflating: leaves/Apple/Apple_scab/image (328).JPG
#   inflating: leaves/Apple/Apple_scab/image (329).JPG
#   inflating: leaves/Apple/Apple_scab/image (33).JPG
#   inflating: leaves/Apple/Apple_scab/image (330).JPG
#   inflating: leaves/Apple/Apple_scab/image (331).JPG
#   inflating: leaves/Apple/Apple_scab/image (332).JPG
#   inflating: leaves/Apple/Apple_scab/image (333).JPG
#   inflating: leaves/Apple/Apple_scab/image (334).JPG
#   inflating: leaves/Apple/Apple_scab/image (335).JPG
#   inflating: leaves/Apple/Apple_scab/image (336).JPG
#   inflating: leaves/Apple/Apple_scab/image (337).JPG
#   inflating: leaves/Apple/Apple_scab/image (338).JPG
#   inflating: leaves/Apple/Apple_scab/image (339).JPG
#   inflating: leaves/Apple/Apple_scab/image (34).JPG
#   inflating: leaves/Apple/Apple_scab/image (340).JPG
#   inflating: leaves/Apple/Apple_scab/image (341).JPG
#   inflating: leaves/Apple/Apple_scab/image (342).JPG
#   inflating: leaves/Apple/Apple_scab/image (343).JPG
#   inflating: leaves/Apple/Apple_scab/image (344).JPG
#   inflating: leaves/Apple/Apple_scab/image (345).JPG
#   inflating: leaves/Apple/Apple_scab/image (346).JPG
#   inflating: leaves/Apple/Apple_scab/image (347).JPG
#   inflating: leaves/Apple/Apple_scab/image (348).JPG
#   inflating: leaves/Apple/Apple_scab/image (349).JPG
#   inflating: leaves/Apple/Apple_scab/image (35).JPG
#   inflating: leaves/Apple/Apple_scab/image (350).JPG
#   inflating: leaves/Apple/Apple_scab/image (351).JPG
#   inflating: leaves/Apple/Apple_scab/image (352).JPG
#   inflating: leaves/Apple/Apple_scab/image (353).JPG
#   inflating: leaves/Apple/Apple_scab/image (354).JPG
#   inflating: leaves/Apple/Apple_scab/image (355).JPG
#   inflating: leaves/Apple/Apple_scab/image (356).JPG
#   inflating: leaves/Apple/Apple_scab/image (357).JPG
#   inflating: leaves/Apple/Apple_scab/image (358).JPG
#   inflating: leaves/Apple/Apple_scab/image (359).JPG
#   inflating: leaves/Apple/Apple_scab/image (36).JPG
#   inflating: leaves/Apple/Apple_scab/image (360).JPG
#   inflating: leaves/Apple/Apple_scab/image (361).JPG
#   inflating: leaves/Apple/Apple_scab/image (362).JPG
#   inflating: leaves/Apple/Apple_scab/image (363).JPG
#   inflating: leaves/Apple/Apple_scab/image (364).JPG
#   inflating: leaves/Apple/Apple_scab/image (365).JPG
#   inflating: leaves/Apple/Apple_scab/image (366).JPG
#   inflating: leaves/Apple/Apple_scab/image (367).JPG
#   inflating: leaves/Apple/Apple_scab/image (368).JPG
#   inflating: leaves/Apple/Apple_scab/image (369).JPG
#   inflating: leaves/Apple/Apple_scab/image (37).JPG
#   inflating: leaves/Apple/Apple_scab/image (370).JPG
#   inflating: leaves/Apple/Apple_scab/image (371).JPG
#   inflating: leaves/Apple/Apple_scab/image (372).JPG
#   inflating: leaves/Apple/Apple_scab/image (373).JPG
#   inflating: leaves/Apple/Apple_scab/image (374).JPG
#   inflating: leaves/Apple/Apple_scab/image (375).JPG
#   inflating: leaves/Apple/Apple_scab/image (376).JPG
#   inflating: leaves/Apple/Apple_scab/image (377).JPG
#   inflating: leaves/Apple/Apple_scab/image (378).JPG
#   inflating: leaves/Apple/Apple_scab/image (379).JPG
#   inflating: leaves/Apple/Apple_scab/image (38).JPG
#   inflating: leaves/Apple/Apple_scab/image (380).JPG
#   inflating: leaves/Apple/Apple_scab/image (381).JPG
#   inflating: leaves/Apple/Apple_scab/image (382).JPG
#   inflating: leaves/Apple/Apple_scab/image (383).JPG
#   inflating: leaves/Apple/Apple_scab/image (384).JPG
#   inflating: leaves/Apple/Apple_scab/image (385).JPG
#   inflating: leaves/Apple/Apple_scab/image (386).JPG
#   inflating: leaves/Apple/Apple_scab/image (387).JPG
#   inflating: leaves/Apple/Apple_scab/image (388).JPG
#   inflating: leaves/Apple/Apple_scab/image (389).JPG
#   inflating: leaves/Apple/Apple_scab/image (39).JPG
#   inflating: leaves/Apple/Apple_scab/image (390).JPG
#   inflating: leaves/Apple/Apple_scab/image (391).JPG
#   inflating: leaves/Apple/Apple_scab/image (392).JPG
#   inflating: leaves/Apple/Apple_scab/image (393).JPG
#   inflating: leaves/Apple/Apple_scab/image (394).JPG
#   inflating: leaves/Apple/Apple_scab/image (395).JPG
#   inflating: leaves/Apple/Apple_scab/image (396).JPG
#   inflating: leaves/Apple/Apple_scab/image (397).JPG
#   inflating: leaves/Apple/Apple_scab/image (398).JPG
#   inflating: leaves/Apple/Apple_scab/image (399).JPG
#   inflating: leaves/Apple/Apple_scab/image (4).JPG
#   inflating: leaves/Apple/Apple_scab/image (40).JPG
#   inflating: leaves/Apple/Apple_scab/image (400).JPG
#   inflating: leaves/Apple/Apple_scab/image (401).JPG
#   inflating: leaves/Apple/Apple_scab/image (402).JPG
#   inflating: leaves/Apple/Apple_scab/image (403).JPG
#   inflating: leaves/Apple/Apple_scab/image (404).JPG
#   inflating: leaves/Apple/Apple_scab/image (405).JPG
#   inflating: leaves/Apple/Apple_scab/image (406).JPG
#   inflating: leaves/Apple/Apple_scab/image (407).JPG
#   inflating: leaves/Apple/Apple_scab/image (408).JPG
#   inflating: leaves/Apple/Apple_scab/image (409).JPG
#   inflating: leaves/Apple/Apple_scab/image (41).JPG
#   inflating: leaves/Apple/Apple_scab/image (410).JPG
#   inflating: leaves/Apple/Apple_scab/image (411).JPG
#   inflating: leaves/Apple/Apple_scab/image (412).JPG
#   inflating: leaves/Apple/Apple_scab/image (413).JPG
#   inflating: leaves/Apple/Apple_scab/image (414).JPG
#   inflating: leaves/Apple/Apple_scab/image (415).JPG
#   inflating: leaves/Apple/Apple_scab/image (416).JPG
#   inflating: leaves/Apple/Apple_scab/image (417).JPG
#   inflating: leaves/Apple/Apple_scab/image (418).JPG
#   inflating: leaves/Apple/Apple_scab/image (419).JPG
#   inflating: leaves/Apple/Apple_scab/image (42).JPG
#   inflating: leaves/Apple/Apple_scab/image (420).JPG
#   inflating: leaves/Apple/Apple_scab/image (421).JPG
#   inflating: leaves/Apple/Apple_scab/image (422).JPG
#   inflating: leaves/Apple/Apple_scab/image (423).JPG
#   inflating: leaves/Apple/Apple_scab/image (424).JPG
#   inflating: leaves/Apple/Apple_scab/image (425).JPG
#   inflating: leaves/Apple/Apple_scab/image (426).JPG
#   inflating: leaves/Apple/Apple_scab/image (427).JPG
#   inflating: leaves/Apple/Apple_scab/image (428).JPG
#   inflating: leaves/Apple/Apple_scab/image (429).JPG
#   inflating: leaves/Apple/Apple_scab/image (43).JPG
#   inflating: leaves/Apple/Apple_scab/image (430).JPG
#   inflating: leaves/Apple/Apple_scab/image (431).JPG
#   inflating: leaves/Apple/Apple_scab/image (432).JPG
#   inflating: leaves/Apple/Apple_scab/image (433).JPG
#   inflating: leaves/Apple/Apple_scab/image (434).JPG
#   inflating: leaves/Apple/Apple_scab/image (435).JPG
#   inflating: leaves/Apple/Apple_scab/image (436).JPG
#   inflating: leaves/Apple/Apple_scab/image (437).JPG
#   inflating: leaves/Apple/Apple_scab/image (438).JPG
#   inflating: leaves/Apple/Apple_scab/image (439).JPG
#   inflating: leaves/Apple/Apple_scab/image (44).JPG
#   inflating: leaves/Apple/Apple_scab/image (440).JPG
#   inflating: leaves/Apple/Apple_scab/image (441).JPG
#   inflating: leaves/Apple/Apple_scab/image (442).JPG
#   inflating: leaves/Apple/Apple_scab/image (443).JPG
#   inflating: leaves/Apple/Apple_scab/image (444).JPG
#   inflating: leaves/Apple/Apple_scab/image (445).JPG
#   inflating: leaves/Apple/Apple_scab/image (446).JPG
#   inflating: leaves/Apple/Apple_scab/image (447).JPG
#   inflating: leaves/Apple/Apple_scab/image (448).JPG
#   inflating: leaves/Apple/Apple_scab/image (449).JPG
#   inflating: leaves/Apple/Apple_scab/image (45).JPG
#   inflating: leaves/Apple/Apple_scab/image (450).JPG
#   inflating: leaves/Apple/Apple_scab/image (451).JPG
#   inflating: leaves/Apple/Apple_scab/image (452).JPG
#   inflating: leaves/Apple/Apple_scab/image (453).JPG
#   inflating: leaves/Apple/Apple_scab/image (454).JPG
#   inflating: leaves/Apple/Apple_scab/image (455).JPG
#   inflating: leaves/Apple/Apple_scab/image (456).JPG
#   inflating: leaves/Apple/Apple_scab/image (457).JPG
#   inflating: leaves/Apple/Apple_scab/image (458).JPG
#   inflating: leaves/Apple/Apple_scab/image (459).JPG
#   inflating: leaves/Apple/Apple_scab/image (46).JPG
#   inflating: leaves/Apple/Apple_scab/image (460).JPG
#   inflating: leaves/Apple/Apple_scab/image (461).JPG
#   inflating: leaves/Apple/Apple_scab/image (462).JPG
#   inflating: leaves/Apple/Apple_scab/image (463).JPG
#   inflating: leaves/Apple/Apple_scab/image (464).JPG
#   inflating: leaves/Apple/Apple_scab/image (465).JPG
#   inflating: leaves/Apple/Apple_scab/image (466).JPG
#   inflating: leaves/Apple/Apple_scab/image (467).JPG
#   inflating: leaves/Apple/Apple_scab/image (468).JPG
#   inflating: leaves/Apple/Apple_scab/image (469).JPG
#   inflating: leaves/Apple/Apple_scab/image (47).JPG
#   inflating: leaves/Apple/Apple_scab/image (470).JPG
#   inflating: leaves/Apple/Apple_scab/image (471).JPG
#   inflating: leaves/Apple/Apple_scab/image (472).JPG
#   inflating: leaves/Apple/Apple_scab/image (473).JPG
#   inflating: leaves/Apple/Apple_scab/image (474).JPG
#   inflating: leaves/Apple/Apple_scab/image (475).JPG
#   inflating: leaves/Apple/Apple_scab/image (476).JPG
#   inflating: leaves/Apple/Apple_scab/image (477).JPG
#   inflating: leaves/Apple/Apple_scab/image (478).JPG
#   inflating: leaves/Apple/Apple_scab/image (479).JPG
#   inflating: leaves/Apple/Apple_scab/image (48).JPG
#   inflating: leaves/Apple/Apple_scab/image (480).JPG
#   inflating: leaves/Apple/Apple_scab/image (481).JPG
#   inflating: leaves/Apple/Apple_scab/image (482).JPG
#   inflating: leaves/Apple/Apple_scab/image (483).JPG
#   inflating: leaves/Apple/Apple_scab/image (484).JPG
#   inflating: leaves/Apple/Apple_scab/image (485).JPG
#   inflating: leaves/Apple/Apple_scab/image (486).JPG
#   inflating: leaves/Apple/Apple_scab/image (487).JPG
#   inflating: leaves/Apple/Apple_scab/image (488).JPG
#   inflating: leaves/Apple/Apple_scab/image (489).JPG
#   inflating: leaves/Apple/Apple_scab/image (49).JPG
#   inflating: leaves/Apple/Apple_scab/image (490).JPG
#   inflating: leaves/Apple/Apple_scab/image (491).JPG
#   inflating: leaves/Apple/Apple_scab/image (492).JPG
#   inflating: leaves/Apple/Apple_scab/image (493).JPG
#   inflating: leaves/Apple/Apple_scab/image (494).JPG
#   inflating: leaves/Apple/Apple_scab/image (495).JPG
#   inflating: leaves/Apple/Apple_scab/image (496).JPG
#   inflating: leaves/Apple/Apple_scab/image (497).JPG
#   inflating: leaves/Apple/Apple_scab/image (498).JPG
#   inflating: leaves/Apple/Apple_scab/image (499).JPG
#   inflating: leaves/Apple/Apple_scab/image (5).JPG
#   inflating: leaves/Apple/Apple_scab/image (50).JPG
#   inflating: leaves/Apple/Apple_scab/image (500).JPG
#   inflating: leaves/Apple/Apple_scab/image (501).JPG
#   inflating: leaves/Apple/Apple_scab/image (502).JPG
#   inflating: leaves/Apple/Apple_scab/image (503).JPG
#   inflating: leaves/Apple/Apple_scab/image (505).JPG
#   inflating: leaves/Apple/Apple_scab/image (506).JPG
#   inflating: leaves/Apple/Apple_scab/image (507).JPG
#   inflating: leaves/Apple/Apple_scab/image (508).JPG
#   inflating: leaves/Apple/Apple_scab/image (509).JPG
#   inflating: leaves/Apple/Apple_scab/image (51).JPG
#   inflating: leaves/Apple/Apple_scab/image (510).JPG
#   inflating: leaves/Apple/Apple_scab/image (511).JPG
#   inflating: leaves/Apple/Apple_scab/image (512).JPG
#   inflating: leaves/Apple/Apple_scab/image (513).JPG
#   inflating: leaves/Apple/Apple_scab/image (514).JPG
#   inflating: leaves/Apple/Apple_scab/image (515).JPG
#   inflating: leaves/Apple/Apple_scab/image (516).JPG
#   inflating: leaves/Apple/Apple_scab/image (517).JPG
#   inflating: leaves/Apple/Apple_scab/image (518).JPG
#   inflating: leaves/Apple/Apple_scab/image (519).JPG
#   inflating: leaves/Apple/Apple_scab/image (52).JPG
#   inflating: leaves/Apple/Apple_scab/image (520).JPG
#   inflating: leaves/Apple/Apple_scab/image (521).JPG
#   inflating: leaves/Apple/Apple_scab/image (522).JPG
#   inflating: leaves/Apple/Apple_scab/image (523).JPG
#   inflating: leaves/Apple/Apple_scab/image (524).JPG
#   inflating: leaves/Apple/Apple_scab/image (525).JPG
#   inflating: leaves/Apple/Apple_scab/image (526).JPG
#   inflating: leaves/Apple/Apple_scab/image (527).JPG
#   inflating: leaves/Apple/Apple_scab/image (528).JPG
#   inflating: leaves/Apple/Apple_scab/image (529).JPG
#   inflating: leaves/Apple/Apple_scab/image (53).JPG
#   inflating: leaves/Apple/Apple_scab/image (530).JPG
#   inflating: leaves/Apple/Apple_scab/image (531).JPG
#   inflating: leaves/Apple/Apple_scab/image (532).JPG
#   inflating: leaves/Apple/Apple_scab/image (533).JPG
#   inflating: leaves/Apple/Apple_scab/image (534).JPG
#   inflating: leaves/Apple/Apple_scab/image (535).JPG
#   inflating: leaves/Apple/Apple_scab/image (536).JPG
#   inflating: leaves/Apple/Apple_scab/image (537).JPG
#   inflating: leaves/Apple/Apple_scab/image (538).JPG
#   inflating: leaves/Apple/Apple_scab/image (539).JPG
#   inflating: leaves/Apple/Apple_scab/image (54).JPG
#   inflating: leaves/Apple/Apple_scab/image (540).JPG
#   inflating: leaves/Apple/Apple_scab/image (541).JPG
#   inflating: leaves/Apple/Apple_scab/image (542).JPG
#   inflating: leaves/Apple/Apple_scab/image (543).JPG
#   inflating: leaves/Apple/Apple_scab/image (544).JPG
#   inflating: leaves/Apple/Apple_scab/image (545).JPG
#   inflating: leaves/Apple/Apple_scab/image (546).JPG
#   inflating: leaves/Apple/Apple_scab/image (547).JPG
#   inflating: leaves/Apple/Apple_scab/image (548).JPG
#   inflating: leaves/Apple/Apple_scab/image (549).JPG
#   inflating: leaves/Apple/Apple_scab/image (55).JPG
#   inflating: leaves/Apple/Apple_scab/image (550).JPG
#   inflating: leaves/Apple/Apple_scab/image (551).JPG
#   inflating: leaves/Apple/Apple_scab/image (552).JPG
#   inflating: leaves/Apple/Apple_scab/image (553).JPG
#   inflating: leaves/Apple/Apple_scab/image (554).JPG
#   inflating: leaves/Apple/Apple_scab/image (555).JPG
#   inflating: leaves/Apple/Apple_scab/image (556).JPG
#   inflating: leaves/Apple/Apple_scab/image (557).JPG
#   inflating: leaves/Apple/Apple_scab/image (558).JPG
#   inflating: leaves/Apple/Apple_scab/image (559).JPG
#   inflating: leaves/Apple/Apple_scab/image (56).JPG
#   inflating: leaves/Apple/Apple_scab/image (560).JPG
#   inflating: leaves/Apple/Apple_scab/image (561).JPG
#   inflating: leaves/Apple/Apple_scab/image (562).JPG
#   inflating: leaves/Apple/Apple_scab/image (563).JPG
#   inflating: leaves/Apple/Apple_scab/image (564).JPG
#   inflating: leaves/Apple/Apple_scab/image (565).JPG
#   inflating: leaves/Apple/Apple_scab/image (566).JPG
#   inflating: leaves/Apple/Apple_scab/image (567).JPG
#   inflating: leaves/Apple/Apple_scab/image (568).JPG
#   inflating: leaves/Apple/Apple_scab/image (569).JPG
#   inflating: leaves/Apple/Apple_scab/image (57).JPG
#   inflating: leaves/Apple/Apple_scab/image (570).JPG
#   inflating: leaves/Apple/Apple_scab/image (571).JPG
#   inflating: leaves/Apple/Apple_scab/image (572).JPG
#   inflating: leaves/Apple/Apple_scab/image (573).JPG
#   inflating: leaves/Apple/Apple_scab/image (574).JPG
#   inflating: leaves/Apple/Apple_scab/image (575).JPG
#   inflating: leaves/Apple/Apple_scab/image (576).JPG
#   inflating: leaves/Apple/Apple_scab/image (577).JPG
#   inflating: leaves/Apple/Apple_scab/image (578).JPG
#   inflating: leaves/Apple/Apple_scab/image (579).JPG
#   inflating: leaves/Apple/Apple_scab/image (58).JPG
#   inflating: leaves/Apple/Apple_scab/image (580).JPG
#   inflating: leaves/Apple/Apple_scab/image (581).JPG
#   inflating: leaves/Apple/Apple_scab/image (582).JPG
#   inflating: leaves/Apple/Apple_scab/image (583).JPG
#   inflating: leaves/Apple/Apple_scab/image (584).JPG
#   inflating: leaves/Apple/Apple_scab/image (585).JPG
#   inflating: leaves/Apple/Apple_scab/image (586).JPG
#   inflating: leaves/Apple/Apple_scab/image (587).JPG
#   inflating: leaves/Apple/Apple_scab/image (588).JPG
#   inflating: leaves/Apple/Apple_scab/image (589).JPG
#   inflating: leaves/Apple/Apple_scab/image (59).JPG
#   inflating: leaves/Apple/Apple_scab/image (590).JPG
#   inflating: leaves/Apple/Apple_scab/image (591).JPG
#   inflating: leaves/Apple/Apple_scab/image (592).JPG
#   inflating: leaves/Apple/Apple_scab/image (593).JPG
#   inflating: leaves/Apple/Apple_scab/image (594).JPG
#   inflating: leaves/Apple/Apple_scab/image (595).JPG
#   inflating: leaves/Apple/Apple_scab/image (596).JPG
#   inflating: leaves/Apple/Apple_scab/image (597).JPG
#   inflating: leaves/Apple/Apple_scab/image (598).JPG
#   inflating: leaves/Apple/Apple_scab/image (599).JPG
#   inflating: leaves/Apple/Apple_scab/image (6).JPG
#   inflating: leaves/Apple/Apple_scab/image (60).JPG
#   inflating: leaves/Apple/Apple_scab/image (600).JPG
#   inflating: leaves/Apple/Apple_scab/image (601).JPG
# ...
#   inflating: leaves/Grape/Grape_spot/image (737).JPG
#   inflating: leaves/Grape/Grape_spot/image (738).JPG
#   inflating: leaves/Grape/Grape_spot/image (739).JPG
#   inflating: leaves/Grape/Grape_spot/image (74).JPG
#   inflating: leaves/Grape/Grape_spot/image (740).JPG
#   inflating: leaves/Grape/Grape_spot/image (741).JPG
#   inflating: leaves/Grape/Grape_spot/image (742).JPG
#   inflating: leaves/Grape/Grape_spot/image (743).JPG
#   inflating: leaves/Grape/Grape_spot/image (744).JPG
#   inflating: leaves/Grape/Grape_spot/image (745).JPG
#   inflating: leaves/Grape/Grape_spot/image (746).JPG
#   inflating: leaves/Grape/Grape_spot/image (747).JPG
#   inflating: leaves/Grape/Grape_spot/image (748).JPG
#   inflating: leaves/Grape/Grape_spot/image (749).JPG
#   inflating: leaves/Grape/Grape_spot/image (75).JPG
#   inflating: leaves/Grape/Grape_spot/image (750).JPG
#   inflating: leaves/Grape/Grape_spot/image (751).JPG
#   inflating: leaves/Grape/Grape_spot/image (752).JPG
#   inflating: leaves/Grape/Grape_spot/image (753).JPG
#   inflating: leaves/Grape/Grape_spot/image (754).JPG
#   inflating: leaves/Grape/Grape_spot/image (755).JPG
#   inflating: leaves/Grape/Grape_spot/image (756).JPG
#   inflating: leaves/Grape/Grape_spot/image (757).JPG
#   inflating: leaves/Grape/Grape_spot/image (758).JPG
#   inflating: leaves/Grape/Grape_spot/image (759).JPG
#   inflating: leaves/Grape/Grape_spot/image (76).JPG
#   inflating: leaves/Grape/Grape_spot/image (760).JPG
#   inflating: leaves/Grape/Grape_spot/image (761).JPG
#   inflating: leaves/Grape/Grape_spot/image (762).JPG
#   inflating: leaves/Grape/Grape_spot/image (763).JPG
#   inflating: leaves/Grape/Grape_spot/image (764).JPG
#   inflating: leaves/Grape/Grape_spot/image (765).JPG
#   inflating: leaves/Grape/Grape_spot/image (766).JPG
#   inflating: leaves/Grape/Grape_spot/image (767).JPG
#   inflating: leaves/Grape/Grape_spot/image (768).JPG
#   inflating: leaves/Grape/Grape_spot/image (769).JPG
#   inflating: leaves/Grape/Grape_spot/image (77).JPG
#   inflating: leaves/Grape/Grape_spot/image (770).JPG
#   inflating: leaves/Grape/Grape_spot/image (771).JPG
#   inflating: leaves/Grape/Grape_spot/image (772).JPG
#   inflating: leaves/Grape/Grape_spot/image (773).JPG
#   inflating: leaves/Grape/Grape_spot/image (774).JPG
#   inflating: leaves/Grape/Grape_spot/image (775).JPG
#   inflating: leaves/Grape/Grape_spot/image (776).JPG
#   inflating: leaves/Grape/Grape_spot/image (777).JPG
#   inflating: leaves/Grape/Grape_spot/image (778).JPG
#   inflating: leaves/Grape/Grape_spot/image (779).JPG
#   inflating: leaves/Grape/Grape_spot/image (78).JPG
#   inflating: leaves/Grape/Grape_spot/image (780).JPG
#   inflating: leaves/Grape/Grape_spot/image (781).JPG
#   inflating: leaves/Grape/Grape_spot/image (782).JPG
#   inflating: leaves/Grape/Grape_spot/image (783).JPG
#   inflating: leaves/Grape/Grape_spot/image (784).JPG
#   inflating: leaves/Grape/Grape_spot/image (785).JPG
#   inflating: leaves/Grape/Grape_spot/image (786).JPG
#   inflating: leaves/Grape/Grape_spot/image (787).JPG
#   inflating: leaves/Grape/Grape_spot/image (788).JPG
#   inflating: leaves/Grape/Grape_spot/image (789).JPG
#   inflating: leaves/Grape/Grape_spot/image (79).JPG
#   inflating: leaves/Grape/Grape_spot/image (790).JPG
#   inflating: leaves/Grape/Grape_spot/image (791).JPG
#   inflating: leaves/Grape/Grape_spot/image (792).JPG
#   inflating: leaves/Grape/Grape_spot/image (793).JPG
#   inflating: leaves/Grape/Grape_spot/image (794).JPG
#   inflating: leaves/Grape/Grape_spot/image (795).JPG
#   inflating: leaves/Grape/Grape_spot/image (796).JPG
#   inflating: leaves/Grape/Grape_spot/image (797).JPG
#   inflating: leaves/Grape/Grape_spot/image (798).JPG
#   inflating: leaves/Grape/Grape_spot/image (799).JPG
#   inflating: leaves/Grape/Grape_spot/image (8).JPG
#   inflating: leaves/Grape/Grape_spot/image (80).JPG
#   inflating: leaves/Grape/Grape_spot/image (800).JPG
#   inflating: leaves/Grape/Grape_spot/image (801).JPG
#   inflating: leaves/Grape/Grape_spot/image (802).JPG
#   inflating: leaves/Grape/Grape_spot/image (803).JPG
#   inflating: leaves/Grape/Grape_spot/image (804).JPG
#   inflating: leaves/Grape/Grape_spot/image (805).JPG
#   inflating: leaves/Grape/Grape_spot/image (806).JPG
#   inflating: leaves/Grape/Grape_spot/image (807).JPG
#   inflating: leaves/Grape/Grape_spot/image (808).JPG
#   inflating: leaves/Grape/Grape_spot/image (809).JPG
#   inflating: leaves/Grape/Grape_spot/image (81).JPG
#   inflating: leaves/Grape/Grape_spot/image (810).JPG
#   inflating: leaves/Grape/Grape_spot/image (811).JPG
#   inflating: leaves/Grape/Grape_spot/image (812).JPG
#   inflating: leaves/Grape/Grape_spot/image (813).JPG
#   inflating: leaves/Grape/Grape_spot/image (814).JPG
#   inflating: leaves/Grape/Grape_spot/image (815).JPG
#   inflating: leaves/Grape/Grape_spot/image (816).JPG
#   inflating: leaves/Grape/Grape_spot/image (817).JPG
#   inflating: leaves/Grape/Grape_spot/image (818).JPG
#   inflating: leaves/Grape/Grape_spot/image (819).JPG
#   inflating: leaves/Grape/Grape_spot/image (82).JPG
#   inflating: leaves/Grape/Grape_spot/image (820).JPG
#   inflating: leaves/Grape/Grape_spot/image (821).JPG
#   inflating: leaves/Grape/Grape_spot/image (822).JPG
#   inflating: leaves/Grape/Grape_spot/image (823).JPG
#   inflating: leaves/Grape/Grape_spot/image (824).JPG
#   inflating: leaves/Grape/Grape_spot/image (825).JPG
#   inflating: leaves/Grape/Grape_spot/image (826).JPG
#   inflating: leaves/Grape/Grape_spot/image (827).JPG
#   inflating: leaves/Grape/Grape_spot/image (828).JPG
#   inflating: leaves/Grape/Grape_spot/image (829).JPG
#   inflating: leaves/Grape/Grape_spot/image (83).JPG
#   inflating: leaves/Grape/Grape_spot/image (830).JPG
#   inflating: leaves/Grape/Grape_spot/image (831).JPG
#   inflating: leaves/Grape/Grape_spot/image (832).JPG
#   inflating: leaves/Grape/Grape_spot/image (833).JPG
#   inflating: leaves/Grape/Grape_spot/image (834).JPG
#   inflating: leaves/Grape/Grape_spot/image (835).JPG
#   inflating: leaves/Grape/Grape_spot/image (836).JPG
#   inflating: leaves/Grape/Grape_spot/image (837).JPG
#   inflating: leaves/Grape/Grape_spot/image (838).JPG
#   inflating: leaves/Grape/Grape_spot/image (839).JPG
#   inflating: leaves/Grape/Grape_spot/image (84).JPG
#   inflating: leaves/Grape/Grape_spot/image (840).JPG
#   inflating: leaves/Grape/Grape_spot/image (841).JPG
#   inflating: leaves/Grape/Grape_spot/image (842).JPG
#   inflating: leaves/Grape/Grape_spot/image (843).JPG
#   inflating: leaves/Grape/Grape_spot/image (844).JPG
#   inflating: leaves/Grape/Grape_spot/image (845).JPG
#   inflating: leaves/Grape/Grape_spot/image (846).JPG
#   inflating: leaves/Grape/Grape_spot/image (847).JPG
#   inflating: leaves/Grape/Grape_spot/image (848).JPG
#   inflating: leaves/Grape/Grape_spot/image (849).JPG
#   inflating: leaves/Grape/Grape_spot/image (85).JPG
#   inflating: leaves/Grape/Grape_spot/image (850).JPG
#   inflating: leaves/Grape/Grape_spot/image (851).JPG
#   inflating: leaves/Grape/Grape_spot/image (852).JPG
#   inflating: leaves/Grape/Grape_spot/image (853).JPG
#   inflating: leaves/Grape/Grape_spot/image (854).JPG
#   inflating: leaves/Grape/Grape_spot/image (855).JPG
#   inflating: leaves/Grape/Grape_spot/image (856).JPG
#   inflating: leaves/Grape/Grape_spot/image (857).JPG
#   inflating: leaves/Grape/Grape_spot/image (858).JPG
#   inflating: leaves/Grape/Grape_spot/image (859).JPG
#   inflating: leaves/Grape/Grape_spot/image (86).JPG
#   inflating: leaves/Grape/Grape_spot/image (860).JPG
#   inflating: leaves/Grape/Grape_spot/image (861).JPG
#   inflating: leaves/Grape/Grape_spot/image (862).JPG
#   inflating: leaves/Grape/Grape_spot/image (863).JPG
#   inflating: leaves/Grape/Grape_spot/image (864).JPG
#   inflating: leaves/Grape/Grape_spot/image (865).JPG
#   inflating: leaves/Grape/Grape_spot/image (866).JPG
#   inflating: leaves/Grape/Grape_spot/image (867).JPG
#   inflating: leaves/Grape/Grape_spot/image (868).JPG
#   inflating: leaves/Grape/Grape_spot/image (869).JPG
#   inflating: leaves/Grape/Grape_spot/image (87).JPG
#   inflating: leaves/Grape/Grape_spot/image (870).JPG
#   inflating: leaves/Grape/Grape_spot/image (871).JPG
#   inflating: leaves/Grape/Grape_spot/image (872).JPG
#   inflating: leaves/Grape/Grape_spot/image (873).JPG
#   inflating: leaves/Grape/Grape_spot/image (874).JPG
#   inflating: leaves/Grape/Grape_spot/image (875).JPG
#   inflating: leaves/Grape/Grape_spot/image (876).JPG
#   inflating: leaves/Grape/Grape_spot/image (877).JPG
#   inflating: leaves/Grape/Grape_spot/image (878).JPG
#   inflating: leaves/Grape/Grape_spot/image (879).JPG
#   inflating: leaves/Grape/Grape_spot/image (88).JPG
#   inflating: leaves/Grape/Grape_spot/image (880).JPG
#   inflating: leaves/Grape/Grape_spot/image (881).JPG
#   inflating: leaves/Grape/Grape_spot/image (882).JPG
#   inflating: leaves/Grape/Grape_spot/image (883).JPG
#   inflating: leaves/Grape/Grape_spot/image (884).JPG
#   inflating: leaves/Grape/Grape_spot/image (885).JPG
#   inflating: leaves/Grape/Grape_spot/image (886).JPG
#   inflating: leaves/Grape/Grape_spot/image (887).JPG
#   inflating: leaves/Grape/Grape_spot/image (888).JPG
#   inflating: leaves/Grape/Grape_spot/image (889).JPG
#   inflating: leaves/Grape/Grape_spot/image (89).JPG
#   inflating: leaves/Grape/Grape_spot/image (890).JPG
#   inflating: leaves/Grape/Grape_spot/image (891).JPG
#   inflating: leaves/Grape/Grape_spot/image (892).JPG
#   inflating: leaves/Grape/Grape_spot/image (893).JPG
#   inflating: leaves/Grape/Grape_spot/image (894).JPG
#   inflating: leaves/Grape/Grape_spot/image (895).JPG
#   inflating: leaves/Grape/Grape_spot/image (896).JPG
#   inflating: leaves/Grape/Grape_spot/image (897).JPG
#   inflating: leaves/Grape/Grape_spot/image (898).JPG
#   inflating: leaves/Grape/Grape_spot/image (899).JPG
#   inflating: leaves/Grape/Grape_spot/image (9).JPG
#   inflating: leaves/Grape/Grape_spot/image (90).JPG
#   inflating: leaves/Grape/Grape_spot/image (900).JPG
#   inflating: leaves/Grape/Grape_spot/image (901).JPG
#   inflating: leaves/Grape/Grape_spot/image (902).JPG
#   inflating: leaves/Grape/Grape_spot/image (903).JPG
#   inflating: leaves/Grape/Grape_spot/image (904).JPG
#   inflating: leaves/Grape/Grape_spot/image (905).JPG
#   inflating: leaves/Grape/Grape_spot/image (906).JPG
#   inflating: leaves/Grape/Grape_spot/image (907).JPG
#   inflating: leaves/Grape/Grape_spot/image (908).JPG
#   inflating: leaves/Grape/Grape_spot/image (909).JPG
#   inflating: leaves/Grape/Grape_spot/image (91).JPG
#   inflating: leaves/Grape/Grape_spot/image (910).JPG
#   inflating: leaves/Grape/Grape_spot/image (911).JPG
#   inflating: leaves/Grape/Grape_spot/image (912).JPG
#   inflating: leaves/Grape/Grape_spot/image (913).JPG
#   inflating: leaves/Grape/Grape_spot/image (914).JPG
#   inflating: leaves/Grape/Grape_spot/image (915).JPG
#   inflating: leaves/Grape/Grape_spot/image (916).JPG
#   inflating: leaves/Grape/Grape_spot/image (917).JPG
#   inflating: leaves/Grape/Grape_spot/image (918).JPG
#   inflating: leaves/Grape/Grape_spot/image (919).JPG
#   inflating: leaves/Grape/Grape_spot/image (92).JPG
#   inflating: leaves/Grape/Grape_spot/image (920).JPG
#   inflating: leaves/Grape/Grape_spot/image (921).JPG
#   inflating: leaves/Grape/Grape_spot/image (922).JPG
#   inflating: leaves/Grape/Grape_spot/image (923).JPG
#   inflating: leaves/Grape/Grape_spot/image (924).JPG
#   inflating: leaves/Grape/Grape_spot/image (925).JPG
#   inflating: leaves/Grape/Grape_spot/image (926).JPG
#   inflating: leaves/Grape/Grape_spot/image (927).JPG
#   inflating: leaves/Grape/Grape_spot/image (928).JPG
#   inflating: leaves/Grape/Grape_spot/image (929).JPG
#   inflating: leaves/Grape/Grape_spot/image (93).JPG
#   inflating: leaves/Grape/Grape_spot/image (930).JPG
#   inflating: leaves/Grape/Grape_spot/image (931).JPG
#   inflating: leaves/Grape/Grape_spot/image (932).JPG
#   inflating: leaves/Grape/Grape_spot/image (933).JPG
#   inflating: leaves/Grape/Grape_spot/image (934).JPG
#   inflating: leaves/Grape/Grape_spot/image (935).JPG
#   inflating: leaves/Grape/Grape_spot/image (936).JPG
#   inflating: leaves/Grape/Grape_spot/image (937).JPG
#   inflating: leaves/Grape/Grape_spot/image (938).JPG
#   inflating: leaves/Grape/Grape_spot/image (939).JPG
#   inflating: leaves/Grape/Grape_spot/image (94).JPG
#   inflating: leaves/Grape/Grape_spot/image (940).JPG
#   inflating: leaves/Grape/Grape_spot/image (941).JPG
#   inflating: leaves/Grape/Grape_spot/image (942).JPG
#   inflating: leaves/Grape/Grape_spot/image (943).JPG
#   inflating: leaves/Grape/Grape_spot/image (944).JPG
#   inflating: leaves/Grape/Grape_spot/image (945).JPG
#   inflating: leaves/Grape/Grape_spot/image (946).JPG
#   inflating: leaves/Grape/Grape_spot/image (947).JPG
#   inflating: leaves/Grape/Grape_spot/image (948).JPG
#   inflating: leaves/Grape/Grape_spot/image (949).JPG
#   inflating: leaves/Grape/Grape_spot/image (95).JPG
#   inflating: leaves/Grape/Grape_spot/image (950).JPG
#   inflating: leaves/Grape/Grape_spot/image (951).JPG
#   inflating: leaves/Grape/Grape_spot/image (952).JPG
#   inflating: leaves/Grape/Grape_spot/image (953).JPG
#   inflating: leaves/Grape/Grape_spot/image (954).JPG
#   inflating: leaves/Grape/Grape_spot/image (955).JPG
#   inflating: leaves/Grape/Grape_spot/image (956).JPG
#   inflating: leaves/Grape/Grape_spot/image (957).JPG
#   inflating: leaves/Grape/Grape_spot/image (958).JPG
#   inflating: leaves/Grape/Grape_spot/image (959).JPG
#   inflating: leaves/Grape/Grape_spot/image (96).JPG
#   inflating: leaves/Grape/Grape_spot/image (960).JPG
#   inflating: leaves/Grape/Grape_spot/image (961).JPG
#   inflating: leaves/Grape/Grape_spot/image (962).JPG
#   inflating: leaves/Grape/Grape_spot/image (963).JPG
#   inflating: leaves/Grape/Grape_spot/image (964).JPG
#   inflating: leaves/Grape/Grape_spot/image (965).JPG
#   inflating: leaves/Grape/Grape_spot/image (966).JPG
#   inflating: leaves/Grape/Grape_spot/image (967).JPG
#   inflating: leaves/Grape/Grape_spot/image (968).JPG
#   inflating: leaves/Grape/Grape_spot/image (969).JPG
#   inflating: leaves/Grape/Grape_spot/image (97).JPG
#   inflating: leaves/Grape/Grape_spot/image (970).JPG
#   inflating: leaves/Grape/Grape_spot/image (971).JPG
#   inflating: leaves/Grape/Grape_spot/image (972).JPG
#   inflating: leaves/Grape/Grape_spot/image (973).JPG
#   inflating: leaves/Grape/Grape_spot/image (974).JPG
#   inflating: leaves/Grape/Grape_spot/image (975).JPG
#   inflating: leaves/Grape/Grape_spot/image (976).JPG
#   inflating: leaves/Grape/Grape_spot/image (977).JPG
#   inflating: leaves/Grape/Grape_spot/image (978).JPG
#   inflating: leaves/Grape/Grape_spot/image (979).JPG
#   inflating: leaves/Grape/Grape_spot/image (98).JPG
#   inflating: leaves/Grape/Grape_spot/image (980).JPG
#   inflating: leaves/Grape/Grape_spot/image (981).JPG
#   inflating: leaves/Grape/Grape_spot/image (982).JPG
#   inflating: leaves/Grape/Grape_spot/image (983).JPG
#   inflating: leaves/Grape/Grape_spot/image (984).JPG
#   inflating: leaves/Grape/Grape_spot/image (985).JPG
#   inflating: leaves/Grape/Grape_spot/image (986).JPG
#   inflating: leaves/Grape/Grape_spot/image (987).JPG
#   inflating: leaves/Grape/Grape_spot/image (988).JPG
#   inflating: leaves/Grape/Grape_spot/image (989).JPG
#   inflating: leaves/Grape/Grape_spot/image (99).JPG
#   inflating: leaves/Grape/Grape_spot/image (990).JPG
#   inflating: leaves/Grape/Grape_spot/image (991).JPG
#   inflating: leaves/Grape/Grape_spot/image (992).JPG
#   inflating: leaves/Grape/Grape_spot/image (993).JPG
#   inflating: leaves/Grape/Grape_spot/image (994).JPG
#   inflating: leaves/Grape/Grape_spot/image (995).JPG
#   inflating: leaves/Grape/Grape_spot/image (996).JPG
#   inflating: leaves/Grape/Grape_spot/image (997).JPG
#   inflating: leaves/Grape/Grape_spot/image (998).JPG
#   inflating: leaves/Grape/Grape_spot/image (999).JPG

# %%
import os
import shutil
from sklearn.model_selection import train_test_split

def split_dataset(source_dir, target_dir, split_ratio=0.8):
    for class_name in ['Apple_Black_rot', 'Apple_healthy','Apple_rust','Apple_scab']:
        class_dir = os.path.join(source_dir, class_name)
        images = os.listdir(class_dir)

        train_images, val_images = train_test_split(images, train_size=split_ratio, random_state=42)

        for split, split_images in [('train', train_images), ('val', val_images)]:
            split_dir = os.path.join(target_dir, split, class_name)
            os.makedirs(split_dir, exist_ok=True)
            for img in split_images:
                shutil.copy(os.path.join(class_dir, img), os.path.join(split_dir, img))

# Define source and target directories
source_dir = "/content/leaves/Apple"
target_dir = "/content/FinalA"

# Split the dataset
split_dataset(source_dir, target_dir)
print("Dataset split into train and val folders!")
# Out:
# Dataset split into train and val folders!

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.78-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: numpy<=2.1.1,>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.5.1+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.20.1+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.13.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.1.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.78-py3-none-any.whl (921 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 921.5/921.5 kB 30.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 82.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 83.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 54.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.3 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.8 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 94.6 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 ultralytics-8.3.78 ultralytics-thop-2.0.14

# %%
from ultralytics import YOLO

# Load a YOLOv8 classification model (choose 'n', 's', 'm', 'l', or 'x' for the model size)
model = YOLO("yolov8s-cls.pt")  # YOLOv8 Nano for classification

# Train the model
model.train(
    data="FinalA",  # Path to your processed dataset folder
    epochs=20,                # Number of epochs              # Patience for early
    imgsz=256,                 # Input image size
    batch=16,                  # Batch size
    project="Apple",   # Save results in the "BlurDetection" folder
    name="app",        # Name of the experiment
    amp=True,                  # Automatic mixed precision - faster and uses less memory
    workers=4                  # Number of data loader workers
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8s-cls.pt to 'yolov8s-cls.pt'...
# 100%|██████████| 12.3M/12.3M [00:00<00:00, 81.1MB/s]
# Ultralytics 8.3.78 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: task=classify, mode=train, model=yolov8s-cls.pt, data=FinalA, epochs=20, time=None, patience=100, batch=16, imgsz=256, save=True, save_period=-1, cache=False, device=None, workers=4, project=Apple, name=app, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=Apple/app
# train: /content/FinalA/train... found 2531 images in 4 classes ✅
# val: /content/FinalA/val... found 633 images in 4 classes ✅
# test: None...
# Overriding model.yaml nc=1000 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    663044  ultralytics.nn.modules.head.Classify         [512, 4]
# YOLOv8s-cls summary: 56 layers, 5,085,860 parameters, 5,085,860 gradients, 12.6 GFLOPs
# Transferred 156/158 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir Apple/app', view at http://localhost:6006/
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 105MB/s]
# AMP: checks passed ✅
# train: Scanning /content/FinalA/train... 2531 images, 0 corrupt: 100%|██████████| 2531/2531 [00:02<00:00, 1172.01it/s]
# train: New cache created: /content/FinalA/train.cache
# val: Scanning /content/FinalA/val... 633 images, 0 corrupt: 100%|██████████| 633/633 [00:00<00:00, 959.78it/s]
# val: New cache created: /content/FinalA/val.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 26 weight(decay=0.0), 27 weight(decay=0.0005), 27 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 256 train, 256 val
# Using 2 dataloader workers
# Logging results to Apple/app
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/20     0.535G      1.432         16        256:   3%|▎         | 4/159 [00:01<00:51,  3.02it/s]
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
#        1/20     0.535G       1.45         16        256:   4%|▍         | 6/159 [00:02<00:32,  4.65it/s]
# 100%|██████████| 755k/755k [00:00<00:00, 20.6MB/s]
#        1/20     0.541G     0.6062          3        256: 100%|██████████| 159/159 [00:21<00:00,  7.48it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 20/20 [00:01<00:00, 13.56it/s]
#                    all      0.976          1
#       Epoch    GPU_mem       loss  Instances       Size
#        2/20     0.539G     0.1094          3        256: 100%|██████████| 159/159 [00:18<00:00,  8.80it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 20/20 [00:01<00:00, 13.53it/s]
#                    all      0.981          1
#       Epoch    GPU_mem       loss  Instances       Size
#        3/20      0.51G    0.08849          3        256: 100%|██████████| 159/159 [00:17<00:00,  9.34it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 20/20 [00:01<00:00, 14.29it/s]
#                    all      0.991          1
#       Epoch    GPU_mem       loss  Instances       Size
#        4/20     0.527G      0.068          3        256: 100%|██████████| 159/159 [00:17<00:00,  8.88it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 20/20 [00:01<00:00, 14.03it/s]
#                    all      0.992          1
#       Epoch    GPU_mem       loss  Instances       Size
#        5/20     0.539G      0.086          3        256: 100%|██████████| 159/159 [00:17<00:00,  8.99it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 20/20 [00:01<00:00, 13.36it/s]
#                    all      0.989          1
#       Epoch    GPU_mem       loss  Instances       Size
#        6/20     0.523G    0.06721          3        256: 100%|██████████| 159/159 [00:17<00:00,  9.11it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 20/20 [00:01<00:00, 13.78it/s]
#                    all      0.997          1
#       Epoch    GPU_mem       loss  Instances       Size
#        7/20     0.527G    0.03338          3        256: 100%|██████████| 159/159 [00:17<00:00,  9.34it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 20/20 [00:01<00:00, 10.15it/s]
#                    all      0.995          1
#       Epoch    GPU_mem       loss  Instances       Size
#        8/20     0.516G     0.0501          3        256: 100%|██████████| 159/159 [00:17<00:00,  9.31it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 20/20 [00:01<00:00, 13.66it/s]
#                    all      0.995          1
#       Epoch    GPU_mem       loss  Instances       Size
#        9/20     0.541G    0.03225          3        256: 100%|██████████| 159/159 [00:17<00:00,  9.28it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 20/20 [00:02<00:00,  9.07it/s]
#                    all      0.997          1
#       Epoch    GPU_mem       loss  Instances       Size
#       10/20     0.516G    0.02287          3        256: 100%|██████████| 159/159 [00:17<00:00,  9.31it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 20/20 [00:01<00:00, 14.23it/s]
#                    all      0.995          1
#       Epoch    GPU_mem       loss  Instances       Size
#       11/20     0.504G    0.01539          3        256: 100%|██████████| 159/159 [00:17<00:00,  9.02it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 20/20 [00:01<00:00, 11.20it/s]
#                    all      0.998          1
#       Epoch    GPU_mem       loss  Instances       Size
#       12/20     0.516G    0.01679          3        256: 100%|██████████| 159/159 [00:16<00:00,  9.77it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 20/20 [00:01<00:00, 14.11it/s]
#                    all      0.997          1
#       Epoch    GPU_mem       loss  Instances       Size
#       13/20     0.539G    0.01965          3        256: 100%|██████████| 159/159 [00:17<00:00,  9.29it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 20/20 [00:02<00:00,  9.43it/s]
#                    all      0.995          1
#       Epoch    GPU_mem       loss  Instances       Size
#       14/20     0.518G    0.01046          3        256: 100%|██████████| 159/159 [00:16<00:00,  9.59it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 20/20 [00:01<00:00, 13.77it/s]
#                    all      0.998          1
#       Epoch    GPU_mem       loss  Instances       Size
#       15/20     0.504G      0.016          3        256: 100%|██████████| 159/159 [00:16<00:00,  9.64it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 20/20 [00:02<00:00,  8.91it/s]
#                    all      0.998          1
#       Epoch    GPU_mem       loss  Instances       Size
#       16/20     0.516G    0.01095          3        256: 100%|██████████| 159/159 [00:16<00:00,  9.66it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 20/20 [00:01<00:00, 13.97it/s]
#                    all      0.997          1
#       Epoch    GPU_mem       loss  Instances       Size
#       17/20     0.539G    0.01221          3        256: 100%|██████████| 159/159 [00:16<00:00,  9.64it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 20/20 [00:02<00:00,  9.89it/s]
#                    all      0.997          1
#       Epoch    GPU_mem       loss  Instances       Size
#       18/20     0.516G   0.008742          3        256: 100%|██████████| 159/159 [00:16<00:00,  9.53it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 20/20 [00:01<00:00, 14.55it/s]
#                    all      0.997          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       19/20     0.504G   0.005372          3        256: 100%|██████████| 159/159 [00:16<00:00,  9.58it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 20/20 [00:01<00:00, 11.33it/s]
#                    all      0.997          1
#       Epoch    GPU_mem       loss  Instances       Size
#       20/20     0.516G   0.009327          3        256: 100%|██████████| 159/159 [00:16<00:00,  9.48it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 20/20 [00:01<00:00, 13.61it/s]
#                    all      0.997          1
# 20 epochs completed in 0.110 hours.
# Optimizer stripped from Apple/app/weights/last.pt, 10.3MB
# Optimizer stripped from Apple/app/weights/best.pt, 10.3MB
#
# Validating Apple/app/weights/best.pt...
# Ultralytics 8.3.78 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8s-cls summary (fused): 30 layers, 5,080,324 parameters, 0 gradients, 12.5 GFLOPs
# train: /content/FinalA/train... found 2531 images in 4 classes ✅
# val: /content/FinalA/val... found 633 images in 4 classes ✅
# test: None...
#                classes   top1_acc   top5_acc: 100%|██████████| 20/20 [00:01<00:00, 13.19it/s]
#                    all      0.998          1
# Speed: 0.2ms preprocess, 0.6ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to Apple/app
# ultralytics.utils.metrics.ClassifyMetrics object with attributes:
#
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x791826a68e50>
# curves: []
# curves_results: []
# fitness: 0.9992101192474365
# keys: ['metrics/accuracy_top1', 'metrics/accuracy_top5']
# results_dict: {'metrics/accuracy_top1': 0.998420238494873, 'metrics/accuracy_top5': 1.0, 'fitness': 0.9992101192474365}
# save_dir: PosixPath('Apple/app')
# speed: {'preprocess': 0.1780398183250952, 'inference': 0.564798838862452, 'loss': 0.00037551816751799576, 'postprocess': 0.0007400300161156636}
# task: 'classify'
# top1: 0.998420238494873
# top5: 1.0

# %%
# # prompt: give me a code to zip a foulder

# import shutil

# def zip_folder(folder_path, zip_path):
#   shutil.make_archive(zip_path, 'zip', folder_path)

# # Example usage:
# zip_folder('/content/Apple', '/content/Apple')

# %%
import os
import shutil
from sklearn.model_selection import train_test_split

def split_dataset(source_dir, target_dir, split_ratio=0.8):
    for class_name in ['Grape_Black_rot', 'Grape_Esca', 'Grape_healthy', 'Grape_spot']:
        class_dir = os.path.join(source_dir, class_name)
        images = os.listdir(class_dir)

        train_images, val_images = train_test_split(images, train_size=split_ratio, random_state=42)

        for split, split_images in [('train', train_images), ('val', val_images)]:
            split_dir = os.path.join(target_dir, split, class_name)
            os.makedirs(split_dir, exist_ok=True)
            for img in split_images:
                shutil.copy(os.path.join(class_dir, img), os.path.join(split_dir, img))

# Define source and target directories
source_dir = "/content/leaves/Grape"
target_dir = "/content/FinalG"

# Split the dataset
split_dataset(source_dir, target_dir)
print("Dataset split into train and val folders!")
# Out:
# Dataset split into train and val folders!

# %%
from ultralytics import YOLO

# Load a YOLOv8 classification model (choose 'n', 's', 'm', 'l', or 'x' for the model size)
model = YOLO("yolov8s-cls.pt")  # YOLOv8 Nano for classification

# Train the model
model.train(
    data="FinalG",  # Path to your processed dataset folder
    epochs=20,                # Number of epochs              # Patience for early
    imgsz=256,                 # Input image size
    batch=16,                  # Batch size
    project="Grape",   # Save results in the "BlurDetection" folder
    name="gra",        # Name of the experiment
    amp=True,                  # Automatic mixed precision - faster and uses less memory
    workers=4                  # Number of data loader workers
)
# Out:
# Ultralytics 8.3.78 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: task=classify, mode=train, model=yolov8s-cls.pt, data=FinalG, epochs=20, time=None, patience=100, batch=16, imgsz=256, save=True, save_period=-1, cache=False, device=None, workers=4, project=Grape, name=gra, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=Grape/gra
# train: /content/FinalG/train... found 3244 images in 4 classes ✅
# val: /content/FinalG/val... found 813 images in 4 classes ✅
# test: None...
# Overriding model.yaml nc=1000 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    663044  ultralytics.nn.modules.head.Classify         [512, 4]
# YOLOv8s-cls summary: 56 layers, 5,085,860 parameters, 5,085,860 gradients, 12.6 GFLOPs
# Transferred 156/158 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir Grape/gra', view at http://localhost:6006/
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Scanning /content/FinalG/train... 3244 images, 0 corrupt: 100%|██████████| 3244/3244 [00:01<00:00, 2562.12it/s]
# train: New cache created: /content/FinalG/train.cache
# val: Scanning /content/FinalG/val... 813 images, 0 corrupt: 100%|██████████| 813/813 [00:00<00:00, 1333.87it/s]
# val: New cache created: /content/FinalG/val.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 26 weight(decay=0.0), 27 weight(decay=0.0005), 27 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 256 train, 256 val
# Using 2 dataloader workers
# Logging results to Grape/gra
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/20     0.641G     0.5086         12        256: 100%|██████████| 203/203 [00:22<00:00,  8.83it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 26/26 [00:01<00:00, 14.87it/s]
#                    all      0.994          1
#       Epoch    GPU_mem       loss  Instances       Size
#        2/20      0.51G    0.07935         12        256: 100%|██████████| 203/203 [00:22<00:00,  8.89it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 26/26 [00:01<00:00, 14.83it/s]
#                    all      0.996          1
#       Epoch    GPU_mem       loss  Instances       Size
#        3/20      0.52G    0.07331         12        256: 100%|██████████| 203/203 [00:22<00:00,  8.94it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 26/26 [00:01<00:00, 14.73it/s]
#                    all      0.995          1
#       Epoch    GPU_mem       loss  Instances       Size
#        4/20     0.523G    0.06836         12        256: 100%|██████████| 203/203 [00:23<00:00,  8.74it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 26/26 [00:01<00:00, 14.77it/s]
#                    all      0.994          1
#       Epoch    GPU_mem       loss  Instances       Size
#        5/20      0.52G    0.06172         12        256: 100%|██████████| 203/203 [00:21<00:00,  9.44it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 26/26 [00:02<00:00, 10.85it/s]
#                    all      0.995          1
#       Epoch    GPU_mem       loss  Instances       Size
#        6/20     0.502G    0.05034         12        256: 100%|██████████| 203/203 [00:21<00:00,  9.65it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 26/26 [00:02<00:00,  9.67it/s]
#                    all      0.995          1
#       Epoch    GPU_mem       loss  Instances       Size
#        7/20       0.5G    0.02854         12        256: 100%|██████████| 203/203 [00:20<00:00,  9.70it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 26/26 [00:02<00:00, 12.69it/s]
#                    all      0.998          1
#       Epoch    GPU_mem       loss  Instances       Size
#        8/20     0.504G    0.01962         12        256: 100%|██████████| 203/203 [00:21<00:00,  9.46it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 26/26 [00:01<00:00, 14.96it/s]
#                    all          1          1
#       Epoch    GPU_mem       loss  Instances       Size
#        9/20      0.52G    0.03565         12        256: 100%|██████████| 203/203 [00:21<00:00,  9.31it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 26/26 [00:01<00:00, 14.45it/s]
#                    all      0.999          1
#       Epoch    GPU_mem       loss  Instances       Size
#       10/20     0.502G    0.01446         12        256: 100%|██████████| 203/203 [00:22<00:00,  9.19it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 26/26 [00:01<00:00, 14.95it/s]
#                    all          1          1
#       Epoch    GPU_mem       loss  Instances       Size
#       11/20     0.553G    0.01796         12        256: 100%|██████████| 203/203 [00:22<00:00,  8.93it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 26/26 [00:01<00:00, 14.76it/s]
#                    all          1          1
#       Epoch    GPU_mem       loss  Instances       Size
#       12/20     0.508G   0.009967         12        256: 100%|██████████| 203/203 [00:21<00:00,  9.24it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 26/26 [00:01<00:00, 14.89it/s]
#                    all          1          1
#       Epoch    GPU_mem       loss  Instances       Size
#       13/20      0.52G   0.006541         12        256: 100%|██████████| 203/203 [00:22<00:00,  9.16it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 26/26 [00:01<00:00, 14.42it/s]
#                    all          1          1
#       Epoch    GPU_mem       loss  Instances       Size
#       14/20     0.502G     0.0108         12        256: 100%|██████████| 203/203 [00:22<00:00,  9.16it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 26/26 [00:01<00:00, 14.81it/s]
#                    all          1          1
#       Epoch    GPU_mem       loss  Instances       Size
#       15/20       0.5G   0.008777         12        256: 100%|██████████| 203/203 [00:22<00:00,  9.19it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 26/26 [00:01<00:00, 14.56it/s]
#                    all          1          1
#       Epoch    GPU_mem       loss  Instances       Size
#       16/20     0.508G   0.007327         12        256: 100%|██████████| 203/203 [00:21<00:00,  9.39it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 26/26 [00:02<00:00, 11.32it/s]
#                    all          1          1
#       Epoch    GPU_mem       loss  Instances       Size
#       17/20      0.52G   0.008306         12        256: 100%|██████████| 203/203 [00:20<00:00,  9.67it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 26/26 [00:02<00:00, 10.04it/s]
#                    all      0.999          1
#       Epoch    GPU_mem       loss  Instances       Size
#       18/20     0.502G    0.00874         12        256: 100%|██████████| 203/203 [00:21<00:00,  9.64it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 26/26 [00:01<00:00, 14.21it/s]
#                    all          1          1
#       Epoch    GPU_mem       loss  Instances       Size
#       19/20       0.5G   0.005759         12        256: 100%|██████████| 203/203 [00:21<00:00,  9.33it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 26/26 [00:01<00:00, 15.21it/s]
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       20/20     0.508G   0.006976         12        256: 100%|██████████| 203/203 [00:22<00:00,  9.08it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 26/26 [00:01<00:00, 15.16it/s]
#                    all          1          1
# 20 epochs completed in 0.138 hours.
# Optimizer stripped from Grape/gra/weights/last.pt, 10.3MB
# Optimizer stripped from Grape/gra/weights/best.pt, 10.3MB
#
# Validating Grape/gra/weights/best.pt...
# Ultralytics 8.3.78 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8s-cls summary (fused): 30 layers, 5,080,324 parameters, 0 gradients, 12.5 GFLOPs
# train: /content/FinalG/train... found 3244 images in 4 classes ✅
# val: /content/FinalG/val... found 813 images in 4 classes ✅
# test: None...
#                classes   top1_acc   top5_acc: 100%|██████████| 26/26 [00:02<00:00, 10.69it/s]
#                    all          1          1
# Speed: 0.1ms preprocess, 0.7ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to Grape/gra
# ultralytics.utils.metrics.ClassifyMetrics object with attributes:
#
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7917d07b2c90>
# curves: []
# curves_results: []
# fitness: 1.0
# keys: ['metrics/accuracy_top1', 'metrics/accuracy_top5']
# results_dict: {'metrics/accuracy_top1': 1.0, 'metrics/accuracy_top5': 1.0, 'fitness': 1.0}
# save_dir: PosixPath('Grape/gra')
# speed: {'preprocess': 0.12354061254658515, 'inference': 0.6743773148839385, 'loss': 0.0004214305040885806, 'postprocess': 0.0007765289052059467}
# task: 'classify'
# top1: 1.0
# top5: 1.0

# %%
# prompt: give me a code to zip a foulder

import shutil

def zip_folder(folder_path, zip_path):
  shutil.make_archive(zip_path, 'zip', folder_path)

# Example usage:
zip_folder('/content/Grape', '/content/Grape')
